# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.mpl_style', 'default')

names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pd.read_csv('pima-indians-diabetes.data', names=names)

# %%
data[["preg", "plas", "pres", "age", "class"]].head()
# Out:
#    preg  plas  pres  age  class
# 0     6   148    72   50      1
# 1     1    85    66   31      0
# 2     8   183    64   32      1
# 3     1    89    66   21      0
# 4     0   137    40   33      1

# %%
data.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
data.boxplot(return_type='axes')

# %%
data["class"].value_counts()
# Out:
# 0    500
# 1    268
# dtype: int64

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011A10390>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012238C88>]], dtype=object)

# %%
data["mass"].hist()

# %%
data.groupby('class').plas.hist(alpha=0.2)
# Out:
# class
# 0    Axes(0.125,0.125;0.775x0.775)
# 1    Axes(0.125,0.125;0.775x0.775)
# Name: plas, dtype: object

# %%
data.groupby('class').hist()
# Out:
# class
# 0    [[Axes(0.125,0.684722;0.215278x0.215278), Axes...
# 1    [[Axes(0.125,0.684722;0.215278x0.215278), Axes...
# dtype: object
